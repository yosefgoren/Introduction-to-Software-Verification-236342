# %%
from framework import *
from q1 import *

# %load_ext autoreload	
# %autoreload 2

# %%
dummy_results = [
	Result(ResultType.Fail, 1, 1), 
	Result(ResultType.Success, 2, 2), 
	Result(ResultType.Unfinished, 3, 3), 
	Result(ResultType.NotApplied, 4, 4)
]
plotResults(dummy_results)
# Out:
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 111.42it/s]

# %%
def foo(x, y):
	while x < 0 and y > 0:
		pass
	return 2*x, 2*y
# pre_condition = lambda x,y: x > 0 or y > 0
pre_condition = lambda x,y: True
post_condition = lambda x,y: x > 0 and y > 0

results = runGrid(foo, pre_condition, post_condition, n=1)

plotResults(results)
# Out:
# Running experiments...
# 100%|██████████| 9/9 [00:09<00:00,  1.09s/it]
# Plotting results...
# 100%|██████████| 4/4 [00:01<00:00,  2.30it/s]
# /home/yosef/miniconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from q1 import Program_1

# %%
Coniditions_A = (lambda x,y: False, lambda x,y: x==1 and y==1)
grid_res_A = runGrid(Program_1, *Coniditions_A, n=1, time_limit_seconds=3)
plotResults(grid_res_A)
# Out:
# Running experiments...
# 100%|██████████| 9/9 [00:00<00:00, 1503.99it/s]
# Plotting results...
# 100%|██████████| 4/4 [00:01<00:00,  2.35it/s]

# %%
Conditions_B = (lambda x,y: True, lambda x,y: y >=0 or x >= 0)
grid_res_B = runGrid(Program_1, *Conditions_B, n=1, time_limit_seconds=3)
plotResults(grid_res_B)
# Out:
# Running experiments...
# 100%|██████████| 9/9 [00:09<00:00,  1.05s/it]
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 31.10it/s]
