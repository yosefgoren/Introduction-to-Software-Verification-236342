# %%
from framework import *
from q1 import *

# %load_ext autoreload	
# %autoreload 2

# %%
dummy_results = [
	Result(ResultType.Fail, 1, 1), 
	Result(ResultType.Success, 2, 2), 
	Result(ResultType.Unfinished, 3, 3), 
	Result(ResultType.NotApplied, 4, 4)
]
plotResults(dummy_results)
# Out:
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 192.44it/s]

# %%
def foo(x, y):
	while x < 0 and y > 0:
		pass
	return 2*x, 2*y
pre_condition = lambda x,y: x > 0 or y > 0
post_condition = lambda x,y: x > 0 and y > 0

results = runGrid(foo, pre_condition, post_condition, n=1)

plotResults(results)
# Out:
# Running experiments...
# 100%|██████████| 9/9 [00:05<00:00,  1.75it/s]
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 46.41it/s]

# %%
from q1 import Program_1

# %%
Coniditions_A = (lambda x,y: False, lambda x,y: x==1 and y==1)
grid_res_A = runGrid(Program_1, *Coniditions_A, n=1, time_limit_seconds=3)
plotResults(grid_res_A)
# Out:
# Running experiments...
# 100%|██████████| 9/9 [00:00<00:00, 23967.45it/s]
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 91.56it/s]

# %%
Conditions_B = (lambda x,y: True, lambda x,y: y >=0 or x >= 0)
grid_res_B = runGrid(Program_1, *Conditions_B, override_points=([-100], [-99]))
plotResults(grid_res_B)
# Out:
# Running experiments...
# 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 130.81it/s]

# %%
Conditions_C = (lambda x,y: x==y, lambda x,y: True)
grid_res_C = runGrid(Program_1, *Conditions_C)
plotResults(grid_res_C)
# Out:
# Running experiments...
# 100%|██████████| 49/49 [00:07<00:00,  6.76it/s]
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 63.13it/s]

# %%
# D.
plotResults(runGrid(Program_1, lambda x,y: 0 < x and x < y and y < 10, lambda x,y: False, n=10))
# Out:
# Running experiments...
# 100%|██████████| 441/441 [00:37<00:00, 11.91it/s]
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 129.04it/s]

# %%
# E.
plotResults(runGrid(Program_1, lambda x,y: x**2 < y**2, lambda x,y: x**2 < y**2, n=10))
# Out:
# Running experiments...
# 100%|██████████| 441/441 [03:26<00:00,  2.14it/s]
# Plotting results...
# 100%|██████████| 4/4 [00:00<00:00, 83.29it/s]
